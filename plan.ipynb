# %% [markdown]
# 1. 리스트 페이지 크롤링
#   https://zdnet.co.kr/news/?lstcode=0020&page=1 페이지 크롤링
#   requests, BeautifulSoup 사용

# %% [markdown]
# 2. 상세 페이지 크롤링
#   위에서 수집한 링크 리스트를 순회
#   기사 본문, 날짜, 기자명 등 추출

# %% [markdown]
# 3. DB 연결 및 테이블 생성 (MySQL)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. 크롤링한 데이터  DB 저장

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. API로 조회 (Flask 기준)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
